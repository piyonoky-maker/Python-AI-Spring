# %%
# %pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in c:\classroom\55python-ai-spring\pythonyolo\lib\site-packages (8.4.19)
# Requirement already satisfied: numpy>=1.23.0 in c:\classroom\55python-ai-spring\pythonyolo\lib\site-packages (from ultralytics) (2.4.2)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\classroom\55python-ai-spring\pythonyolo\lib\site-packages (from ultralytics) (3.10.8)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\classroom\55python-ai-spring\pythonyolo\lib\site-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in c:\classroom\55python-ai-spring\pythonyolo\lib\site-packages (from ultralytics) (12.1.1)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\classroom\55python-ai-spring\pythonyolo\lib\site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in c:\classroom\55python-ai-spring\pythonyolo\lib\site-packages (from ultralytics) (2.32.5)
# Requirement already satisfied: scipy>=1.4.1 in c:\classroom\55python-ai-spring\pythonyolo\lib\site-packages (from ultralytics) (1.17.1)
# Requirement already satisfied: torch>=1.8.0 in c:\classroom\55python-ai-spring\pythonyolo\lib\site-packages (from ultralytics) (2.10.0)
# Requirement already satisfied: torchvision>=0.9.0 in c:\classroom\55python-ai-spring\pythonyolo\lib\site-packages (from ultralytics) (0.25.0)
# Requirement already satisfied: psutil>=5.8.0 in c:\classroom\55python-ai-spring\pythonyolo\lib\site-packages (from ultralytics) (7.2.2)
# Requirement already satisfied: polars>=0.20.0 in c:\classroom\55python-ai-spring\pythonyolo\lib\site-packages (from ultralytics) (1.38.1)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in c:\classroom\55python-ai-spring\pythonyolo\lib\site-packages (from ultralytics) (2.0.18)
# Requirement already satisfied: contourpy>=1.0.1 in c:\classroom\55python-ai-spring\pythonyolo\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\classroom\55python-ai-spring\pythonyolo\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\classroom\55python-ai-spring\pythonyolo\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\classroom\55python-ai-spring\pythonyolo\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\classroom\55python-ai-spring\pythonyolo\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (26.0)
# Requirement already satisfied: pyparsing>=3 in c:\classroom\55python-ai-spring\pythonyolo\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\classroom\55python-ai-spring\pythonyolo\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.38.1 in c:\classroom\55python-ai-spring\pythonyolo\lib\site-packages (from polars>=0.20.0->ultralytics) (1.38.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\classroom\55python-ai-spring\pythonyolo\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\classroom\55python-ai-spring\pythonyolo\lib\site-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\classroom\55python-ai-spring\pythonyolo\lib\site-packages (from requests>=2.23.0->ultralytics) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\classroom\55python-ai-spring\pythonyolo\lib\site-packages (from requests>=2.23.0->ultralytics) (2026.2.25)
# Requirement already satisfied: filelock in c:\classroom\55python-ai-spring\pythonyolo\lib\site-packages (from torch>=1.8.0->ultralytics) (3.25.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\classroom\55python-ai-spring\pythonyolo\lib\site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\classroom\55python-ai-spring\pythonyolo\lib\site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\classroom\55python-ai-spring\pythonyolo\lib\site-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in c:\classroom\55python-ai-spring\pythonyolo\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\classroom\55python-ai-spring\pythonyolo\lib\site-packages (from torch>=1.8.0->ultralytics) (2026.2.0)
# Requirement already satisfied: setuptools in c:\classroom\55python-ai-spring\pythonyolo\lib\site-packages (from torch>=1.8.0->ultralytics) (82.0.0)
# Requirement already satisfied: six>=1.5 in c:\classroom\55python-ai-spring\pythonyolo\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\classroom\55python-ai-spring\pythonyolo\lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\classroom\55python-ai-spring\pythonyolo\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\classroom\55python-ai-spring\pythonyolo\lib\site-packages (4.13.0.92)
# Requirement already satisfied: numpy>=2 in c:\classroom\55python-ai-spring\pythonyolo\lib\site-packages (from opencv-python) (2.4.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from ultralytics import YOLO
# 사전 학습 모델 코드

model = YOLO('./pythonYolo/yolov8n.pt')
# 이미지 분석
result = model('./bus01.jpg')
# 결과 출력

output_path = "bus01_result.jpg"
annotated = results[0].plot
cv2.imwrite(output_path, ann)
print(f'결과 저장 :{output_path}')
# Out:
# image 1/1 c:\ClassRoom\55Python-AI-Spring\bus01.jpg: 512x640 8 persons, 2 cars, 61.4ms
# Speed: 3.4ms preprocess, 61.4ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 11
#       7 # 결과 출력
#       8 # result[0].show()
#      10 output_path = "bus01_result.jpg"
# ---> 11 ann = results[0].plot
#      12 cv2.imwrite(output_path, ann)
#      13 print(f'결과 저장 :{output_path}')
#
# NameError: name 'results' is not defined
